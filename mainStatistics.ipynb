# %%
datasetsNames = {1:"1402", 2:"200213_3M_data", 3:"1704/M3M", 4:"200211_Veolia_M3M", 5:"3M"}
datasetNumber = 5

# %%
# %run classes/Shapefile.ipynb
# %run classes/StatisticsDiam.ipynb
inputFolder = "6-FinallRep"
outputFolder = ""

# %%
statistics = Statistics(datasetNumber, inputFolder, outputFolder)

# %%
statistics.read_shapefile("Pipes")
# Out:
# The shapefile Data SIG/3M/6-FinallRep/Pipes.shp is opned

# %%
statistics.read_shapefile("Nodes")
# Out:
# The shapefile Data SIG/3M/6-FinallRep/Nodes.shp is opned

# %%
statistics.calculate_perpendicular_distance(2,2)
# Out:
# True

# %%
statistics.summarize_distances_by_category()
# Out:
# [18, 19, 20, 1010, 1049, 1429, 1454, 1631, 2083, 2127, 2493, 2499, 3144, 3739, 3818, 3851, 4158, 4213, 4539, 4884, 5038, 5041, 5296, 5466, 5678, 5684, 5793, 5816, 6325, 6360, 6381, 6386, 6611, 6752, 6806, 6846, 7086, 7088, 7362, 7436, 7501, 7566, 7623, 7726, 7732, 8111, 8274, 8636, 8967, 8984, 9189, 9637, 9647, 9649, 9741, 9753, 9766, 9770, 9901, 10521, 10702, 11183, 11410, 11646, 11752, 11833, 11841, 12176, 12322, 12608, 12630, 12946, 13017, 13119, 13529, 14191, 14396, 15043, 15624, 15656, 16219, 16324, 16327, 16642, 17276, 18335, 18565, 18848, 18901, 18971, 19048, 19174, 19390, 19497, 19842, 20277, 21169, 21548, 22931, 23389, 23718, 23891, 23996, 24021, 24084, 25470, 26120, 27835, 28018, 29874, 29900, 30241, 30838, 31081, 31083, 31428, 32145, 32568, 32841, 33086, 34511, 34565, 34961, 34990, 34993, 35216, 35349, 35996, 36021, 36775, 37579, 37886, 39719, 39819, 39963, 39964, 40078, 40079, 40459, 40524, 40570, 40571, 40572, 40597, 40598, 40608, 41712, 42017, 42116, 43624, 43844, 43845
# ...

# %%
statistics.count_pipes_by_diameter()
# Out:
# +------------+---------+
# |   Diameter |   Count |
# +============+=========+
# |        200 |   28713 |
# +------------+---------+
# |        150 |    9684 |
# +------------+---------+
# |        300 |    2223 |
# +------------+---------+
# |        160 |    2142 |
# +------------+---------+
# |        400 |    1851 |
# +------------+---------+
# |        250 |    1245 |
# +------------+---------+
# |        500 |    1161 |
# +------------+---------+
# |        nan |    1012 |
# +------------+---------+
# |        600 |     779 |
# +------------+---------+
# |        800 |     440 |
# +------------+---------+
# |       1000 |     277 |
# +------------+---------+
# |        315 |     220 |
# +------------+---------+
# |       1200 |     203 |
# +------------+---------+
# |        700 |     115 |
# +------------+---------+
# |       1500 |      86 |
# +------------+---------+
# |        125 |      76 |
# +------------+---------+
# |        350 |      71 |
# +------------+---------+
# ...
