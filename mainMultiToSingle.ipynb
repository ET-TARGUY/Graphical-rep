# %%
datasetsNames = {1:"3M"}
datasetNumber = 1

# %%
# %run classes/Shapefile.ipynb
# %run classes/MultiToSingleLineString.ipynb
inputFolder = "3-RemovedRepPs"
outputFolder = "6-FinallRep"

# %%
multiToSingle = MultiToSingleLineString(datasetNumber, inputFolder, outputFolder)

# %%
multiToSingle.multiToSingleLineString()
# Out:
# The shapefile Data SIG/200211_Veolia_M3M/3-RemovedRepPs/Pipes.shp is opned
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# LineString
# ...
